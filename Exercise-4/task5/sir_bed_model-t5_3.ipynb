# %%
from sir_model_visualization import *

# %%
# Task 5.3 - Plot for b = 0.022
SIM0 = (195.3,0.052,4.4)
plotSimulation(init=SIM0)
plotTrajectory(init=SIM0, lines=True, opacity=0.1)
# Out:
# Reproduction number R0= 0.9956709956709958
# Globally asymptotically stable if beta <=d+nu+mu0. This is False

# %%
# Task 5.3 - Plot for b = 0.022
SIM0 = (195.7, 0.03, 3.92)
plotSimulation(init=SIM0)
plotTrajectory(init=SIM0, lines=True, opacity=0.1)
# Out:
# Reproduction number R0= 0.9956709956709958
# Globally asymptotically stable if beta <=d+nu+mu0. This is False

# %%
# Task 5.3 - Plot for b = 0.022
SIM0 = (193, 0.08, 6.21)
plotSimulation(init=SIM0)
plotTrajectory(init=SIM0, lines=True, opacity=0.1)
# Out:
# Reproduction number R0= 0.9956709956709958
# Globally asymptotically stable if beta <=d+nu+mu0. This is False

# %%
# Task 5.3 - Plot for multiple b
SIM0 = (195.3,0.052,4.4)
#SIM0 = (195.7, 0.03, 3.92)
#SIM0 = (193, 0.08, 6.21)
b0 = 0.01
b1 = 0.03
inc = 0.001
n = int((b1-b0)/inc)
for i in range(n):
    b_i = b0 + i*inc
    #plotSimulation(init=SIM0, new_b=b_i, info=False)
    plotTrajectory(init=SIM0, new_b=b_i, lines=True, opacity=0.1)
